# %%
# %cd /content/drive/"My Drive"/
# %cd gitprojects
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/gitprojects

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/gitprojects/.git/

# %%
username=input("Enter username\t")
password=input("Enter password\t")
emailid=input("Enter emailid\t")
# Out:
# Enter username	sonalgan
# Enter password	sonarsh786
# Enter emailid	sonalgan2000@gmail.com

# %%
url="https://{0}:{1}@github.com/{0}/DeepLearning.git".format(username,password)
# !git remote add origin url
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://sonalgan:sonarsh786@github.com/sonalgan/DeepLearning.git (fetch)
# origin	https://sonalgan:sonarsh786@github.com/sonalgan/DeepLearning.git (push)

# %%
# !git config --global user.email emailid
# !git config --global user.name username

# %%
# !git add .!git commit -m 'First commit'
